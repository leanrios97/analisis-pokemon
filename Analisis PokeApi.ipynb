# %%
import requests 
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Obtener Pokemons

# %%
CantPokemon_get = 1025
url = f"https://pokeapi.co/api/v2/pokemon?limit={CantPokemon_get}&offset=0"

# %%
def obtenerPokemons(url):
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        pokemons = data['results']
        return pokemons
    else: 
        raise ValueError(f'Error al realizar la solicitud: {response.status_code}')

# %%
pokemons = obtenerPokemons(url)

# %%
len(pokemons)
# Out:
# 1025

# %%
pokemons[147:]
# Out:
# [{'name': 'dragonair', 'url': 'https://pokeapi.co/api/v2/pokemon/148/'},
#  {'name': 'dragonite', 'url': 'https://pokeapi.co/api/v2/pokemon/149/'},
#  {'name': 'mewtwo', 'url': 'https://pokeapi.co/api/v2/pokemon/150/'},
#  {'name': 'mew', 'url': 'https://pokeapi.co/api/v2/pokemon/151/'},
#  {'name': 'chikorita', 'url': 'https://pokeapi.co/api/v2/pokemon/152/'},
#  {'name': 'bayleef', 'url': 'https://pokeapi.co/api/v2/pokemon/153/'},
#  {'name': 'meganium', 'url': 'https://pokeapi.co/api/v2/pokemon/154/'},
#  {'name': 'cyndaquil', 'url': 'https://pokeapi.co/api/v2/pokemon/155/'},
#  {'name': 'quilava', 'url': 'https://pokeapi.co/api/v2/pokemon/156/'},
#  {'name': 'typhlosion', 'url': 'https://pokeapi.co/api/v2/pokemon/157/'},
#  {'name': 'totodile', 'url': 'https://pokeapi.co/api/v2/pokemon/158/'},
#  {'name': 'croconaw', 'url': 'https://pokeapi.co/api/v2/pokemon/159/'},
#  {'name': 'feraligatr', 'url': 'https://pokeapi.co/api/v2/pokemon/160/'},
# ...

# %%
count = 0
for pokemon in pokemons: 
    count += 1
    print(f"id:{count} {pokemon['name']}")
# Out:
# id:1 bulbasaur
# id:2 ivysaur
# id:3 venusaur
# id:4 charmander
# id:5 charmeleon
# id:6 charizard
# id:7 squirtle
# id:8 wartortle
# id:9 blastoise
# id:10 caterpie
# id:11 metapod
# id:12 butterfree
# id:13 weedle
# id:14 kakuna
# id:15 beedrill
# id:16 pidgey
# id:17 pidgeotto
# id:18 pidgeot
# id:19 rattata
# id:20 raticate
# id:21 spearow
# id:22 fearow
# id:23 ekans
# id:24 arbok
# id:25 pikachu
# id:26 raichu
# id:27 sandshrew
# id:28 sandslash
# id:29 nidoran-f
# id:30 nidorina
# id:31 nidoqueen
# id:32 nidoran-m
# id:33 nidorino
# id:34 nidoking
# id:35 clefairy
# id:36 clefable
# id:37 vulpix
# id:38 ninetales
# id:39 jigglypuff
# id:40 wigglytuff
# id:41 zubat
# id:42 golbat
# id:43 oddish
# id:44 gloom
# id:45 vileplume
# id:46 paras
# id:47 parasect
# id:48 venonat
# id:49 venomoth
# id:50 diglett
# id:51 dugtrio
# id:52 meowth
# id:53 persian
# id:54 psyduck
# id:55 golduck
# id:56 mankey
# id:57 primeape
# id:58 growlithe
# id:59 arcanine
# id:60 poliwag
# ...

# %%
count
# Out:
# 151

# %%
pokemons_name = [pokemon['name'] for pokemon in pokemons]

# %%
pokemons[34]['name']
# Out:
# 'clefairy'

# %%
response = requests.get(pokemons[148]['url'])

if response.status_code == 200:
    data = response.json()
    #pokemons = data['results']
    
else: 
    raise ValueError(f'Error al realizar la solicitud: {response.status_code}')

# %%
data
# Out:
# {'abilities': [{'ability': {'name': 'inner-focus',
#     'url': 'https://pokeapi.co/api/v2/ability/39/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'multiscale',
#     'url': 'https://pokeapi.co/api/v2/ability/136/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 300,
#  'forms': [{'name': 'dragonite',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/149/'}],
#  'game_indices': [{'game_index': 66,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 66,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 66,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 149,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 149,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 149,
# ...

# %%
list(data.keys())
# Out:
# ['abilities',
#  'base_experience',
#  'forms',
#  'game_indices',
#  'height',
#  'held_items',
#  'id',
#  'is_default',
#  'location_area_encounters',
#  'moves',
#  'name',
#  'order',
#  'past_abilities',
#  'past_types',
#  'species',
#  'sprites',
#  'stats',
#  'types',
#  'weight']

# %%
data['location_area_encounters']
# Out:
# 'https://pokeapi.co/api/v2/pokemon/149/encounters'

# %% [markdown]
# ##### Funciones para obtener los datos.

# %%
def obtenerNombre(data, count):
    try:
        idPoxedex = count + 1
        name = data['name'].capitalize()
        return idPoxedex, name
    
    except Exception as e:
        print("No se pudo obtener el nombre.")
        name = np.nan
        return name

# %%
def obtenerTipo(data):
    try:
        tipoCant = len(data['types'])
        
        if tipoCant == 1:
            tipo1 = data['types'][0]['type']['name']
            tipo2 = np.nan
            return tipo1, tipo2
            
        if tipoCant >= 1: 
            tipo1 = data['types'][0]['type']['name']
            tipo2 = data['types'][1]['type']['name']
            return tipo1, tipo2
            
    except Exception as e:
        print("No se puede obtener el tipo")
        name = np.nan
        return name

# %%
def obtenerGeneracion(idPokedex):
    n_dict_generation = {'1':[151,0,151],
                         '2':[100,152,251], 
                         '3':[135,252,386],
                         '4':[107, 387, 493],
                         '5':[156, 494, 649],
                         '6':[72, 650, 721],
                         '7':[88, 722, 809],
                         '8':[96, 810, 905],
                         '9':[120, 906, 1025]}
    try:
        if idPokedex > n_dict_generation['1'][1] and idPokedex <= n_dict_generation['1'][2]:
            generation = int(1)
            return generation
            
        if idPokedex > n_dict_generation['2'][1] and idPokedex <= n_dict_generation['2'][2]:
            generation = int(2)
            return generation
            
        if idPokedex > n_dict_generation['3'][1] and idPokedex <= n_dict_generation['3'][2]:
            generation = int(3)
            return generation
            
        if idPokedex > n_dict_generation['4'][1] and idPokedex <= n_dict_generation['4'][2]:
            generation = int(4)
            return generation
            
        if idPokedex > n_dict_generation['5'][1] and idPokedex <= n_dict_generation['5'][2]:
            generation = int(5)
            return generation
            
        if idPokedex > n_dict_generation['6'][1] and idPokedex <= n_dict_generation['6'][2]:
            generation = int(6)
            return generation
            
        if idPokedex > n_dict_generation['7'][1] and idPokedex <= n_dict_generation['7'][2]:
            generation = int(7)
            return generation
            
        if idPokedex > n_dict_generation['8'][1] and idPokedex <= n_dict_generation['8'][2]:
            generation = int(8)
            return generation

        if idPokedex > n_dict_generation['9'][1] and idPokedex <= n_dict_generation['9'][2]:
            generation = int(9)
            return generation
        
    except Exception as e:
        print(f"Error: {e}")
        return np.nan

# %% [markdown]
# ## Armado DataFrame

# %%
columns = ['IdPokedex', 'Nombre', 'Generación','Tipo1', 'Tipo2']

# %%
df_pokemons = pd.DataFrame(columns=columns)
df_pokemons
# Out:
# Empty DataFrame
# Columns: [IdPokedex, Nombre, Generación, Tipo1, Tipo2]
# Index: []

# %%
idPokedex = 0
for pokemon in pokemons:
    
    response = requests.get(pokemon['url'])

    if response.status_code == 200:
        data = response.json()
        
        idPokedex, name = obtenerNombre(data, idPokedex)
        generation = obtenerGeneracion(idPokedex)
        tipo1, tipo2 = obtenerTipo(data)
        
        nueva_fila = pd.Series([idPokedex, name, generation, tipo1, tipo2], index = df_pokemons.columns)
        df_pokemons = df_pokemons.append(nueva_fila, ignore_index=True)
        
        
    else: 
        raise ValueError(f'Error al realizar la solicitud: {response.status_code}')
# Out:
# C:\Users\Lean\AppData\Local\Temp\ipykernel_5724\1259029550.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pokemons = df_pokemons.append(nueva_fila, ignore_index=True)
# C:\Users\Lean\AppData\Local\Temp\ipykernel_5724\1259029550.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pokemons = df_pokemons.append(nueva_fila, ignore_index=True)
# C:\Users\Lean\AppData\Local\Temp\ipykernel_5724\1259029550.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_pokemons = df_pokemons.append(nueva_fila, ignore_index=True)
# ...

# %%
df_pokemons.to_csv("df_pokemons.csv", sep=';')

# %% [markdown]
# ## Analisis Pokemon

# %%
df_pokemons = pd.read_csv('df_pokemons.csv', sep=';')
df_pokemons
# Out:
#       Unnamed: 0  IdPokedex        Nombre  Generación     Tipo1    Tipo2
# 0              0          1     Bulbasaur         1.0     grass   poison
# 1              1          2       Ivysaur         1.0     grass   poison
# 2              2          3      Venusaur         1.0     grass   poison
# 3              3          4    Charmander         1.0      fire      NaN
# 4              4          5    Charmeleon         1.0      fire      NaN
# ...          ...        ...           ...         ...       ...      ...
# 1020        1020       1021   Raging-bolt         9.0  electric   dragon
# 1021        1021       1022  Iron-boulder         9.0      rock  psychic
# 1022        1022       1023    Iron-crown         9.0     steel  psychic
# 1023        1023       1024     Terapagos         9.0    normal      NaN
# 1024        1024       1025     Pecharunt         9.0    poison    ghost
#
# [1025 rows x 6 columns]

# %%
# vamos a ver cuantos datos nan tenemos. 7
df_pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1025 non-null   int64
#  1   IdPokedex   1025 non-null   int64
#  2   Nombre      1025 non-null   object
#  3   Generación  1017 non-null   float64
#  4   Tipo1       1025 non-null   object
#  5   Tipo2       526 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 48.2+ KB

# %%
# Vamos a ver Cuales son los tipos de Pokemon que hay
tipo_pokemon = [x for x in df_pokemons['Tipo1'].unique()]
tipo_pokemon
# Out:
# ['grass',
#  'fire',
#  'water',
#  'bug',
#  'normal',
#  'poison',
#  'electric',
#  'ground',
#  'fairy',
#  'fighting',
#  'psychic',
#  'rock',
#  'ghost',
#  'ice',
#  'dragon',
#  'dark',
#  'steel',
#  'flying']

# %%
tipo_pokemon_tradu = ['Hierba',
'Fuego',
'Agua',
'Bicho',
'Normal',
'Veneno',
'Eléctrico',
'Tierra',
'Hada',
'Lucha',
'Psíquico',
'Roca',
'Fantasma',
'Hielo',
'Dragón',
'Siniestro',
'Acero',
'Volador']

# %%
cant_tipo1_pokemons = df_pokemons.groupby(['Tipo1'], as_index=False)['IdPokedex'].count()
cant_tipo1_pokemons.sort_values(by='IdPokedex' ,ascending=False)
# Out:
#        Tipo1  IdPokedex
# 17     water        134
# 12    normal        118
# 9      grass        103
# 0        bug         83
# 6       fire         66
# 14   psychic         60
# 3   electric         59
# 15      rock         58
# 1       dark         45
# 13    poison         42
# 5   fighting         40
# 10    ground         40
# 2     dragon         37
# 16     steel         36
# 8      ghost         35
# 11       ice         31
# 4      fairy         29
# 7     flying          9

# %%
fig = px.pie(cant_tipo1_pokemons, values='IdPokedex', names='Tipo1', title='Porcentajes tipo1 Pokemon')
fig.show()

# %%
cant_tipo2_pokemons = df_pokemons.groupby(['Tipo2'], as_index=False)['IdPokedex'].count()
cant_tipo2_pokemons.sort_values(by='IdPokedex' ,ascending=False)
# Out:
#        Tipo2  IdPokedex
# 0        bug          9
# 3   electric         10
# 12    normal         13
# 6       fire         15
# 15      rock         16
# 11       ice         17
# 17     water         20
# 9      grass         24
# 1       dark         24
# 16     steel         29
# 8      ghost         30
# 2     dragon         33
# 5   fighting         33
# 10    ground         35
# 4      fairy         35
# 13    poison         41
# 14   psychic         42
# 7     flying        100

# %%
fig1 = px.pie(cant_tipo2_pokemons, values='IdPokedex', names='Tipo2', title='Porcentajes tipo2 Pokemon')
fig1.show()

# %%
cant_tipo1_tipo2_pokemons = df_pokemons.groupby(['Tipo1','Tipo2'], as_index=False)['IdPokedex'].count()
cant_tipo1_tipo2_pokemons.sort_values(by='IdPokedex' ,ascending=False)
# Out:
#      Tipo1     Tipo2  IdPokedex
# 0      bug      dark          1
# 1      bug  electric          4
# 2      bug     fairy          2
# 3      bug  fighting          4
# 4      bug      fire          2
# ..     ...       ...        ...
# 180  water       ice          4
# 181  water    poison          3
# 182  water   psychic          6
# 183  water      rock          5
# 184  water     steel          1
#
# [185 rows x 3 columns]

# %%
fig2 = px.sunburst(cant_tipo1_tipo2_pokemons, path=['Tipo1', 'Tipo2'], values='IdPokedex')
fig2.show()

# %%
cant_tipo2_tipo1_pokemons = df_pokemons.groupby(['Tipo2','Tipo1'], as_index=False)['IdPokedex'].count()
cant_tipo2_tipo1_pokemons.sort_values(by='IdPokedex' ,ascending=False)
# Out:
#      Tipo2   Tipo1  IdPokedex
# 0      bug    fire          2
# 1      bug     ice          2
# 2      bug  poison          1
# 3      bug    rock          2
# 4      bug   water          2
# ..     ...     ...        ...
# 180  water  flying          1
# 181  water     ice          4
# 182  water  normal          1
# 183  water  poison          3
# 184  water    rock          6
#
# [185 rows x 3 columns]

# %%
fig3 = px.sunburst(cant_tipo2_tipo1_pokemons, path=['Tipo2', 'Tipo1'], values='IdPokedex')
fig3.show()

# %%
cant_gen_pokemon = df_pokemons.groupby(['Generación'], as_index=False)['IdPokedex'].count()
cant_gen_pokemon
# Out:
#    Generación  IdPokedex
# 0         1.0        151
# 1         2.0         99
# 2         3.0        134
# 3         4.0        106
# 4         5.0        155
# 5         6.0         71
# 6         7.0         87
# 7         8.0         95
# 8         9.0        119

# %%
fig4 = px.pie(cant_gen_pokemon, values='IdPokedex', names='Generación', title='Cantidad de Pokemos por generación.')
fig4.show()
